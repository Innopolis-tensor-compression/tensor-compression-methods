# %%
import pandas as pd

df = pd.read_json("results.json")
df_stats_original = df['flopco_stats_original'].apply(lambda x: pd.Series(x))
df_stats_compressed = df['flopco_stats_compressed'].apply(lambda x: pd.Series(x))
df_stats = pd.concat([df_stats_original, df_stats_compressed], axis=1, keys=['original', 'compressed'])
df = pd.concat([df, df_stats], axis=1)
df.drop(columns=['flopco_stats_original', 'flopco_stats_compressed'], inplace=True)
df_compression_ratio = df['compression_ratio'].apply(lambda x: pd.Series(x))
df = pd.concat([df, df_compression_ratio], axis=1)
df.drop(columns=['compression_ratio'], inplace=True)

# %%
df
# Out:
#                  model   accuracy  time_original  time_compressed  \
# 0             resnet18  99.439063      16.696094        13.459114
# 1             resnet34  91.984375      26.310976        19.368004
# 2             resnet50  66.125000      54.086506        45.917069
# 3            resnet101  29.128125      82.257173        65.202029
# 4            resnet152  87.932812     116.459303        90.186255
# 5                vgg11  99.553125      60.634592        51.448701
# 6                vgg13  59.178125      93.975541        86.085626
# 7                vgg16  38.042187     113.959790        96.497843
# 8                vgg19  61.056250     131.330920       104.863916
# 9         mobilenet_v2  73.107812      18.900251        20.688517
# 10  mobilenet_v3_large   0.000000      13.091360        14.841469
# 11  mobilenet_v3_small   0.000000       4.101734         5.942415
# 12     efficientnet_b0  57.309375      23.497179        25.159787
# 13     efficientnet_b1  49.475000      33.286304        35.808252
# 14     efficientnet_b2  47.017187      35.614020        37.013671
# 15     efficientnet_b3  92.775000      48.553467        50.308023
# 16     efficientnet_b4  98.893750      65.583233        65.970891
#
#     (original, total_flops)  (original, total_params)  (original, total_macs)  \
# 0                3628147200                  11679912              1814073344
# 1                7327523328                  21780648              3663761408
# 2                8178370560                  25503912              4089184256
# 3               15602812928                  44443816              7801405440
# 4               23027255296                  60041384             11513626624
# 5               15225639424                 132863336              7609090048
# 6               22629208576                 133047848             11308466176
# 7               30954109440                 138357544             15470264320
# 8               39279010304                 143667240             19632062464
# 9                 601549824                   3470760               300774272
# 10                433186840                   5458632               216589760
# 11                113025288                   2530744                56510400
# 12                771640124                   5246532               385814752
# 13               1139318800                   7732136               569651680
# 14               1317943698                   9042426               658963440
# 15               1925438096                  12145936               962708240
# 16               3007451696                  19216416              1503710432
#
#                                     (original, flops)  \
# 0   {'conv1': [236027904], 'layer1.0.conv1': [2312...
# 1   {'conv1': [236027904], 'layer1.0.conv1': [2312...
# 2   {'conv1': [236027904], 'layer1.0.conv1': [2569...
# 3   {'conv1': [236027904], 'layer1.0.conv1': [2569...
# 4   {'conv1': [236027904], 'layer1.0.conv1': [2569...
# 5   {'features.0': [176619520], 'features.3': [185...
# 6   {'features.0': [176619520], 'features.2': [370...
# 7   {'features.0': [176619520], 'features.2': [370...
# 8   {'features.0': [176619520], 'features.2': [370...
# 9   {'features.0.0': [21676032], 'features.1.conv....
# 10  {'features.0.0': [10838016], 'features.1.block...
# 11  {'features.0.0': [10838016], 'features.1.block...
# 12  {'features.0.0': [21676032], 'features.1.0.blo...
# 13  {'features.0.0': [21676032], 'features.1.0.blo...
# 14  {'features.0.0': [21676032], 'features.1.0.blo...
# 15  {'features.0.0': [27095040], 'features.1.0.blo...
# 16  {'features.0.0': [32514048], 'features.1.0.blo...
#
#                                      (original, macs)  \
# 0   {'conv1': [118013952], 'layer1.0.conv1': [1156...
# 1   {'conv1': [118013952], 'layer1.0.conv1': [1156...
# 2   {'conv1': [118013952], 'layer1.0.conv1': [1284...
# 3   {'conv1': [118013952], 'layer1.0.conv1': [1284...
# 4   {'conv1': [118013952], 'layer1.0.conv1': [1284...
# 5   {'features.0': [86704128], 'features.3': [9248...
# 6   {'features.0': [86704128], 'features.2': [1849...
# 7   {'features.0': [86704128], 'features.2': [1849...
# 8   {'features.0': [86704128], 'features.2': [1849...
# 9   {'features.0.0': [10838016], 'features.1.conv....
# 10  {'features.0.0': [5419008], 'features.1.block....
# 11  {'features.0.0': [5419008], 'features.1.block....
# 12  {'features.0.0': [10838016], 'features.1.0.blo...
# 13  {'features.0.0': [10838016], 'features.1.0.blo...
# 14  {'features.0.0': [10838016], 'features.1.0.blo...
# 15  {'features.0.0': [13547520], 'features.1.0.blo...
# 16  {'features.0.0': [16257024], 'features.1.0.blo...
#
#                                    (original, params)  ...  \
# 0   {'conv1': 9408, 'layer1.0.conv1': 36864, 'laye...  ...
# 1   {'conv1': 9408, 'layer1.0.conv1': 36864, 'laye...  ...
# 2   {'conv1': 9408, 'layer1.0.conv1': 4096, 'layer...  ...
# 3   {'conv1': 9408, 'layer1.0.conv1': 4096, 'layer...  ...
# 4   {'conv1': 9408, 'layer1.0.conv1': 4096, 'layer...  ...
# 5   {'features.0': 1792, 'features.3': 73856, 'fea...  ...
# 6   {'features.0': 1792, 'features.2': 36928, 'fea...  ...
# 7   {'features.0': 1792, 'features.2': 36928, 'fea...  ...
# 8   {'features.0': 1792, 'features.2': 36928, 'fea...  ...
# 9   {'features.0.0': 864, 'features.1.conv.0.0': 2...  ...
# 10  {'features.0.0': 432, 'features.1.block.0.0': ...  ...
# 11  {'features.0.0': 432, 'features.1.block.0.0': ...  ...
# 12  {'features.0.0': 864, 'features.1.0.block.0.0'...  ...
# 13  {'features.0.0': 864, 'features.1.0.block.0.0'...  ...
# 14  {'features.0.0': 864, 'features.1.0.block.0.0'...  ...
# 15  {'features.0.0': 1080, 'features.1.0.block.0.0...  ...
# 16  {'features.0.0': 1296, 'features.1.0.block.0.0...  ...
#
#    (compressed, total_macs)  \
# 0                 333795496
# 1                 645987726
# 2                 459821582
# 3                 797965682
# 4                1147442208
# 5                1499618148
# 6                2095888564
# 7                2763583732
# 8                3422629812
# 9                  52265088
# 10                 38818096
# 11                 16309200
# 12                 64444904
# 13                 91656672
# 14                 95185324
# 15                124929504
# 16                172307488
#
#                                   (compressed, flops)  \
# 0   {'conv1.0': [903168], 'conv1.1.0': [903168], '...
# 1   {'conv1.0': [602112], 'conv1.1.0': [602112], '...
# 2   {'conv1.0': [903168], 'conv1.1.0': [903168], '...
# 3   {'conv1.0': [903168], 'conv1.1.0': [903168], '...
# 4   {'conv1.0': [903168], 'conv1.1.0': [903168], '...
# 5   {'features.0.0': [1053696], 'features.0.1.0': ...
# 6   {'features.0.0': [1053696], 'features.0.1.0': ...
# 7   {'features.0.0': [1053696], 'features.0.1.0': ...
# 8   {'features.0.0': [1053696], 'features.0.1.0': ...
# 9   {'features.0.0.0': [602112], 'features.0.0.1.0...
# 10  {'features.0.0.0': [602112], 'features.0.0.1.0...
# 11  {'features.0.0.0': [903168], 'features.0.0.1.0...
# 12  {'features.0.0.0': [903168], 'features.0.0.1.0...
# 13  {'features.0.0.0': [602112], 'features.0.0.1.0...
# 14  {'features.0.0.0': [903168], 'features.0.0.1.0...
# 15  {'features.0.0.0': [903168], 'features.0.0.1.0...
# 16  {'features.0.0.0': [903168], 'features.0.0.1.0...
#
#                                    (compressed, macs)  \
# 0   {'conv1.0': [451584], 'conv1.1.0': [451584], '...
# 1   {'conv1.0': [301056], 'conv1.1.0': [301056], '...
# 2   {'conv1.0': [451584], 'conv1.1.0': [451584], '...
# 3   {'conv1.0': [451584], 'conv1.1.0': [451584], '...
# 4   {'conv1.0': [451584], 'conv1.1.0': [451584], '...
# 5   {'features.0.0': [451584], 'features.0.1.0': [...
# 6   {'features.0.0': [451584], 'features.0.1.0': [...
# 7   {'features.0.0': [451584], 'features.0.1.0': [...
# 8   {'features.0.0': [451584], 'features.0.1.0': [...
# 9   {'features.0.0.0': [301056], 'features.0.0.1.0...
# 10  {'features.0.0.0': [301056], 'features.0.0.1.0...
# 11  {'features.0.0.0': [451584], 'features.0.0.1.0...
# 12  {'features.0.0.0': [451584], 'features.0.0.1.0...
# 13  {'features.0.0.0': [301056], 'features.0.0.1.0...
# 14  {'features.0.0.0': [451584], 'features.0.0.1.0...
# 15  {'features.0.0.0': [451584], 'features.0.0.1.0...
# 16  {'features.0.0.0': [451584], 'features.0.0.1.0...
#
#                                  (compressed, params)  \
# 0   {'conv1.0': 9, 'conv1.1.0': 9, 'conv1.1.1': 14...
# 1   {'conv1.0': 6, 'conv1.1.0': 6, 'conv1.1.1': 14...
# 2   {'conv1.0': 9, 'conv1.1.0': 9, 'conv1.1.1': 14...
# 3   {'conv1.0': 9, 'conv1.1.0': 9, 'conv1.1.1': 14...
# 4   {'conv1.0': 9, 'conv1.1.0': 9, 'conv1.1.1': 14...
# 5   {'features.0.0': 12, 'features.0.1.0': 12, 'fe...
# 6   {'features.0.0': 12, 'features.0.1.0': 12, 'fe...
# 7   {'features.0.0': 12, 'features.0.1.0': 12, 'fe...
# 8   {'features.0.0': 12, 'features.0.1.0': 12, 'fe...
# 9   {'features.0.0.0': 6, 'features.0.0.1.0': 6, '...
# 10  {'features.0.0.0': 6, 'features.0.0.1.0': 6, '...
# 11  {'features.0.0.0': 9, 'features.0.0.1.0': 9, '...
# 12  {'features.0.0.0': 9, 'features.0.0.1.0': 9, '...
# 13  {'features.0.0.0': 6, 'features.0.0.1.0': 6, '...
# 14  {'features.0.0.0': 9, 'features.0.0.1.0': 9, '...
# 15  {'features.0.0.0': 9, 'features.0.0.1.0': 9, '...
# 16  {'features.0.0.0': 9, 'features.0.0.1.0': 9, '...
#
#                          (compressed, relative_flops)  \
# 0   {'conv1.0': 0.0013528752157390001, 'conv1.1.0'...
# 1   {'conv1.0': 0.00046603962982000004, 'conv1.1.0...
# 2   {'conv1.0': 0.00098208307749, 'conv1.1.0': 0.0...
# 3   {'conv1.0': 0.000565918347976, 'conv1.1.0': 0....
# 4   {'conv1.0': 0.00039355672455600003, 'conv1.1.0...
# 5   {'features.0.0': 0.00034964960384100004, 'feat...
# 6   {'features.0.0': 0.000249799584205, 'features....
# 7   {'features.0.0': 0.00018962488201100002, 'feat...
# 8   {'features.0.0': 0.000153197839057, 'features....
# 9   {'features.0.0.0': 0.005760103446755, 'feature...
# 10  {'features.0.0.0': 0.007754822164259, 'feature...
# 11  {'features.0.0.0': 0.027685056730934004, 'feat...
# 12  {'features.0.0.0': 0.007006705418823001, 'feat...
# 13  {'features.0.0.0': 0.003284326299589, 'feature...
# 14  {'features.0.0.0': 0.004743838259553, 'feature...
# 15  {'features.0.0.0': 0.0036143956329890005, 'fea...
# 16  {'features.0.0.0': 0.002620567190682, 'feature...
#
#                           (compressed, relative_macs)  \
# 0   {'conv1.0': 0.0013528762533090001, 'conv1.1.0'...
# 1   {'conv1.0': 0.000466039814508, 'conv1.1.0': 0....
# 2   {'conv1.0': 0.00098208526454, 'conv1.1.0': 0.0...
# 3   {'conv1.0': 0.0005659190741980001, 'conv1.1.0'...
# 4   {'conv1.0': 0.000393557075773, 'conv1.1.0': 0....
# 5   {'features.0.0': 0.00030113265873800004, 'feat...
# 6   {'features.0.0': 0.00021546183692900002, 'feat...
# 7   {'features.0.0': 0.00016340521720800002, 'feat...
# 8   {'features.0.0': 0.000131940649385, 'features....
# 9   {'features.0.0.0': 0.005760173980765001, 'feat...
# 10  {'features.0.0.0': 0.007755558129383001, 'feat...
# 11  {'features.0.0.0': 0.027688911779854, 'feature...
# 12  {'features.0.0.0': 0.007007287961822001, 'feat...
# 13  {'features.0.0.0': 0.003284605402212, 'feature...
# 14  {'features.0.0.0': 0.004744260785412, 'feature...
# 15  {'features.0.0.0': 0.003614710581097, 'feature...
# 16  {'features.0.0.0': 0.002620803107523, 'feature...
#
#                         (compressed, relative_params)    params      flops  \
# 0   {'conv1.0': 3.891213769016686e-06, 'conv1.1.0'...  5.049893   5.434682
# 1   {'conv1.0': 1.522849596774807e-06, 'conv1.1.0'...  5.528109   5.671563
# 2   {'conv1.0': 2.2562209652564526e-06, 'conv1.1.0...  6.393607   8.892963
# 3   {'conv1.0': 1.571495996090118e-06, 'conv1.1.0'...  7.760364   9.776606
# 4   {'conv1.0': 1.255772717416814e-06, 'conv1.1.0'...  8.377592  10.034159
# 5   {'features.0.0': 9.587124644995764e-08, 'featu...  1.061481   5.052348
# 6   {'features.0.0': 9.585166226791408e-08, 'featu...  1.062738   5.364704
# 7   {'features.0.0': 9.520101972985601e-08, 'featu...  1.097648   5.570553
# 8   {'features.0.0': 9.456683209426483e-08, 'featu...  1.132180   5.710812
# 9   {'features.0.0.0': 4.2809837986168145e-06, 'fe...  2.476378   5.754725
# 10  {'features.0.0.0': 2.239875761557759e-06, 'fea...  2.037776   5.579173
# 11  {'features.0.0.0': 5.248661154017296e-06, 'fea...  1.475891   3.464595
# 12  {'features.0.0.0': 5.634106124022952e-06, 'fea...  3.284391   5.986323
# 13  {'features.0.0.0': 3.451534983895713e-06, 'fea...  4.447956   6.214616
# 14  {'features.0.0.0': 4.7213511037994276e-06, 'fe...  4.743608   6.922424
# 15  {'features.0.0.0': 4.106530707039643e-06, 'fea...  5.541962   7.705427
# 16  {'features.0.0.0': 3.265417487253987e-06, 'fea...  6.972180   8.726205
#
#          macs
# 0    5.434685
# 1    5.671565
# 2    8.892980
# 3    9.776618
# 4   10.034167
# 5    5.074018
# 6    5.395547
# 7    5.597900
# 8    5.735958
# 9    5.754784
# 10   5.579608
# 11   3.464940
# 12   5.986738
# 13   6.215060
# 14   6.922952
# 15   7.706012
# 16   8.726901
#
# [17 rows x 25 columns]

# %%
df.iloc[0]
# Out:
# model                                                                     resnet18
# accuracy                                                                 99.439063
# time_original                                                            16.696094
# time_compressed                                                          13.459114
# (original, total_flops)                                                 3628147200
# (original, total_params)                                                  11679912
# (original, total_macs)                                                  1814073344
# (original, flops)                {'conv1': [236027904], 'layer1.0.conv1': [2312...
# (original, macs)                 {'conv1': [118013952], 'layer1.0.conv1': [1156...
# (original, params)               {'conv1': 9408, 'layer1.0.conv1': 36864, 'laye...
# (original, relative_flops)       {'conv1': 0.065054665918736, 'layer1.0.conv1':...
# (original, relative_macs)        {'conv1': 0.065054675099178, 'layer1.0.conv1':...
# (original, relative_params)      {'conv1': 0.000805485520781, 'layer1.0.conv1':...
# (compressed, total_flops)                                                667591504
# (compressed, total_params)                                                 2312903
# (compressed, total_macs)                                                 333795496
# (compressed, flops)              {'conv1.0': [903168], 'conv1.1.0': [903168], '...
# (compressed, macs)               {'conv1.0': [451584], 'conv1.1.0': [451584], '...
# (compressed, params)             {'conv1.0': 9, 'conv1.1.0': 9, 'conv1.1.1': 14...
# (compressed, relative_flops)     {'conv1.0': 0.0013528752157390001, 'conv1.1.0'...
# (compressed, relative_macs)      {'conv1.0': 0.0013528762533090001, 'conv1.1.0'...
# (compressed, relative_params)    {'conv1.0': 3.891213769016686e-06, 'conv1.1.0'...
# params                                                                    5.049893
# flops                                                                     5.434682
# macs                                                                      5.434685
# Name: 0, dtype: object
